# %%
from climso.detection import Prominences, ProminenceSpeed

import os, re
from scipy.ndimage import gaussian_filter1d
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import pandas as pd
import numpy as np

# %%
base_dir='example_data/CLIMSO/2023/data_calibrated/2023-07-28/' #2024-08-09
files = [base_dir+file for file in os.listdir(base_dir) if file.startswith('imoa_06563_c1_')]

def extract_timestamp(file_path):
    match = re.search(r'\d{8}_\d{8}', file_path)
    if match:
        return match.group(0)
    return ''

files = sorted(files, key=extract_timestamp)
    
files
# Out:
# ['example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_05561065_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_05582861_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_05592702_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06002858_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06012778_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06022719_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06032878_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06042813_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06052740_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06062883_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06072894_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06083174_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06092740_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06102976_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06113016_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06123052_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06132970_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06143098_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06200977_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06212725_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06222716_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06232722_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06292765_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06302620_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06412965_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06422918_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06432936_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06442921_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06493188_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06502773_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06512869_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_06522744_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_13462541_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_13493317_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_13523212_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_13532537_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_13552765_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_13563127_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_13572802_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_13583036_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_13592658_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14002985_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14012710_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14022905_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14032827_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14042901_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14052938_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14062703_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14072864_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14083022_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14092828_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14102888_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14112924_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14123074_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14133038_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14142929_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14163049_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14173033_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14183030_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14192792_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14203212_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14213028_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14223345_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14232627_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14242993_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14252844_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14263101_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14272743_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14283171_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14293041_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14302855_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14312899_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14322921_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14333035_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14343001_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_14352742_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15032952_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15042735_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15052965_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15062839_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15072714_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15082743_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15092780_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15112986_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15122844_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15133090_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15142940_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15153015_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15162933_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15173246_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15182915_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15192731_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15202764_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15213120_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15222671_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15232927_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15242737_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15252792_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15262728_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15273138_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15282835_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15292895_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15303032_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15312954_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15322932_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15332920_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15342960_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15352904_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15363003_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15373011_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15382922_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15393036_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15402888_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15412878_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15422845_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15432826_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15442918_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15453075_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15462814_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15472859_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15482658_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15492829_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15512947_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15522972_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15533275_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15552929_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15562902_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15572948_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15582721_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_15593016_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16002730_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16013090_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16022842_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16032975_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16042875_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16053053_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16062972_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16072812_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16092779_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16102725_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16112921_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16122772_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16133190_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16142938_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16153047_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16162780_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16172790_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16182869_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16192904_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16202763_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16212795_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16222957_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16232788_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16242829_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16252889_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16262889_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16272881_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16283082_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16292722_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16302911_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16312761_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16322771_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16332960_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16342819_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16352802_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16362744_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16372953_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16413128_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16433081_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16443027_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16453248_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16462815_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16473009_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16482987_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16492825_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16502857_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16532722_bri1.fts.bz2',
#  'example_data/CLIMSO/2023/data_calibrated/2023-07-28/imoa_06563_c1_20230728_16542634_bri1.fts.bz2']

# %%
file = files[117]

# %%
from astropy.io import fits

with fits.open(file) as hdul:
    data = np.flip(hdul[0].data, axis=0)

plt.figure(figsize=(8,8))
plt.imshow(data, origin='lower', cmap='grey')

plt.axis('off')
# Out:
# (-0.5, 2047.5, -0.5, 2047.5)

# %%
images = []
for file in files:
    images.append(Prominences(file))

# %%
# sort by date
images.sort(key=lambda x: x.date_obs)

# %%
fig, ax = plt.subplots(figsize=(10,4))
plt.plot(images[-5].array[30,:], color='b')

xticks = np.linspace(0, 360, 19)
ax.set_xticks(np.linspace(0, 720, 19))
ax.set_xticklabels([f'{xtick:.0f}°' for xtick in xticks])

plt.axhline(20000, linestyle='--',color='r')
plt.xlabel('Degrees')
plt.ylabel('Value')
plt.title('Intensity at 1.03 solar radius')
# Out:
# Text(0.5, 1.0, 'Intensity at 1.03 solar radius')

# %%
fig, ax = plt.subplots(figsize=(10,4))
plt.imshow(images[-5].array, origin='lower')


xticks = np.linspace(0, 360, 19)
ax.set_xticks(np.linspace(0, 720, 19))
ax.set_xticklabels([f'{xtick:.0f}°' for xtick in xticks])
plt.xlabel('Degrees')

yticks = np.linspace(1, 1+(len(images[-5].array)-1)*1e-3, 7)
ax.set_yticks(np.linspace(0, len(images[-5].array), 7))
ax.set_yticklabels([f'{ytick:.2f}' for ytick in yticks])

plt.ylabel('Solar Radius');

# %%
images[-5].plot()

# %%
images[-5].prominences
# Out:
#      deg  radius    value
# 0  152.0   1.032  15694.0
# 1  221.0   1.043  17632.0
# 2  245.5   1.052  15104.0
# 3  298.5   1.205  17910.0

# %%
base_prominence = images[-5].prominences.iloc[3]
last_deg = base_prominence.deg
date_rad = []
for n in range(2, len(images)):
    min_diff = np.inf
    closest_prom = None
    for idx, prominence in images[-n].prominences.iterrows():
        diff = abs(last_deg-prominence.deg)
        if diff<5 and diff<min_diff:
            min_diff=diff
            closest_prom=prominence
    if closest_prom is not None:
        last_deg = closest_prom.deg
        date_rad.insert(0,(images[-n].date_obs, closest_prom.radius))
        
date_rad.append((images[-5].date_obs, base_prominence.radius))

# %%
times = []
radiuses = []

for time, radius in date_rad:
    times.append(time)
    radiuses.append(radius)

smoothed_max_radiuses = gaussian_filter1d(radiuses, sigma=1, radius=5)

plt.figure(figsize=(10, 5))
#plt.plot(times, smoothed_max_radiuses, marker='', linestyle='-', color='0.8', label='Smoothed (Gaussian)')
plt.plot(times, radiuses, marker='+', linestyle='-', color='b', label='Original')


plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

time_format = mdates.DateFormatter('%H:%M')
plt.gca().xaxis.set_major_formatter(time_format)

plt.xlabel('Time (HH:mm)')
plt.ylabel('Solar radius')
plt.title('Height of prominence')
plt.legend();

# %%
speeds = []
times = []
for n in range(1,len(date_rad)):
    distance = (date_rad[n][1] - date_rad[n-1][1])*696e3 # km
    time = abs(date_rad[n][0] - date_rad[n-1][0])
    if time.seconds == 0 : continue # to avoid division by zero
    
    speed = distance / time.seconds # km/s
    speeds.append(speed)
    times.append(date_rad[n][0])

# %%
# Generate smoothed values
smoothed_values = gaussian_filter1d(speeds, sigma=1, radius=5)

# Plot the original and smoothed data
plt.figure(figsize=(10, 5))
#plt.plot(times[-len(speeds):], smoothed_values, marker='', linestyle='-', color='0.8', label='Smoothed (Gaussian)')
plt.plot(times[-len(speeds):], speeds, marker='+', linestyle='-', color = 'r', label='Original')
plt.title('Velocity')
plt.xlabel('Time (HH:mm)')
plt.ylabel('Velocity (km/s)')
plt.grid(True)
plt.xticks(rotation=45)
time_format = mdates.DateFormatter('%H:%M')
plt.gca().xaxis.set_major_formatter(time_format)
plt.tight_layout()
plt.legend();

# %%
idx=0

fig, ax = plt.subplots(figsize=(13,6))
plt.imshow(images[idx].array, origin='lower')

for _, prom in images[idx].prominences.iterrows():
    plt.plot(int(prom.deg*2), int((prom.radius-1)*1e3), 'ro')
    plt.axhline(y=int((prom.radius-1)*1e3), color='red', linestyle='-', linewidth=0.5)

xticks = np.linspace(0, 360, 19)
ax.set_xticks(np.linspace(0, 720, 19))
ax.set_xticklabels([f'{xtick:.0f}°' for xtick in xticks])
plt.xlabel('Degrees')

yticks = np.linspace(1, 1+(len(images[idx].array)-1)*1e-3, 7)
ax.set_yticks(np.linspace(0, len(images[idx].array), 7))
ax.set_yticklabels([f'{ytick:.2f}' for ytick in yticks])

plt.ylabel('Solar Radius')

plt.title(images[idx].date_obs);

# %% [markdown]
# ## Create GIF

# %%
import os
if not os.path.exists('frames'):
    os.makedirs('frames')
filenames = []
for idx, file in enumerate(images):
    
    fig, ax = plt.subplots(figsize=(13,6))
    plt.imshow(images[idx].array, origin='lower')

    for _, prom in images[idx].prominences.iterrows():
        plt.plot(int(prom.deg*2), int((prom.radius-1)*1e3), 'ro')
        plt.axhline(y=int((prom.radius-1)*1e3), color='red', linestyle='-', linewidth=0.5)


    xticks = np.linspace(0, 360, 19)
    ax.set_xticks(np.linspace(0, 720, 19))
    ax.set_xticklabels([f'{xtick:.0f}°' for xtick in xticks])
    plt.xlabel('Degrees')

    yticks = np.linspace(1, 1+(len(images[idx].array)-1)*1e-3, 7)
    ax.set_yticks(np.linspace(0, len(images[idx].array), 7))
    ax.set_yticklabels([f'{ytick:.2f}' for ytick in yticks])

    plt.ylabel('Solar Radius');
    
    plt.title(images[idx].date_obs);
    
    filename = f'frames/frame_{idx}.png'
    filenames.append(filename)
    plt.savefig(filename)
    plt.close()

# %%
import imageio

with imageio.get_writer('prominence.gif', mode='I', duration=0.1, loop=0) as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)
# Out:
# C:\Users\lherrington\AppData\Local\Temp\ipykernel_2080\1843818749.py:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)

# %% [markdown]
# ## final tests

# %%
images[-1].prominences
# Out:
#      deg  radius    value
# 0  152.0   1.033  16708.0
# 1  217.5   1.104  15008.0
# 2  246.0   1.058  15727.0
# 3  304.0   1.276  15049.0

# %%
images[-2].plot()

# %%
prom_speed = ProminenceSpeed(images, 3)

prom_speed.plotDistances()

# %%
prom_speed.plotSpeed()
